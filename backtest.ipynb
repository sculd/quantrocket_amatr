# %%
from quantrocket.moonshot import backtest as backtest_moonshot
import pyfolio
from moonchart import Tearsheet

# %%
# !mkdir -p /codeload/moonshot

# !cp amatr.py /codeload/moonshot/

# %%
backtest_moonshot(
    "amatr", 
    start_date="2016-01-01", 
    end_date="2023-02-01", 
    filepath_or_buffer="moonshot_amatr_results.csv")

# %%
Tearsheet.from_moonshot_csv("moonshot_amatr_results.csv")
